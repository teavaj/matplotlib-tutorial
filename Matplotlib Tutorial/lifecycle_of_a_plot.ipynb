# %%
import numpy as np
import matplotlib.pyplot as plt


data = {
    "Barton LLC": 109438.50,
    "Frami, Hills and Schmidt": 103569.59,
    "Fritsch, Russel and Anderson": 112214.71,
    "Jerde-Hilpert": 112591.43,
    "Keeling LLC": 100934.30,
    "Koepp Ltd": 103660.54,
    "Kulas Inc": 137351.96,
    "Trantow-Barrows": 123381.38,
    "White-Trantow": 135841.99,
    "Will LLC": 104437.60,
}
group_data = list(data.values())
group_names = list(data.keys())
group_mean = np.mean(group_data)

# %%
fig, ax = plt.subplots()
ax.barh(group_names, group_data)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.style.use("grayscale")
fig, ax = plt.subplots()
ax.barh(group_names, group_data)
# Out:
# <BarContainer object of 10 artists>

# %%
fig, ax = plt.subplots()
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment="right")
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
plt.rcParams.update({"figure.autolayout": True})

fig, ax = plt.subplots()
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment="right")
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
fig, ax = plt.subplots()
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment="right")
ax.set(
    xlim=[-10000, 140000],
    xlabel="Total Revenue",
    ylabel="Company",
    title="Company Revenue",
)
# Out:
# [(-10000.0, 140000.0),
#  Text(0.5, 0, 'Total Revenue'),
#  Text(0, 0.5, 'Company'),
#  Text(0.5, 1.0, 'Company Revenue')]

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment="right")
ax.set(
    xlim=[-10000, 140000],
    xlabel="Total Revenue",
    ylabel="Company",
    title="Company Revenue",
)
# Out:
# [(-10000.0, 140000.0),
#  Text(0.5, 0, 'Total Revenue'),
#  Text(0, 0.5, 'Company'),
#  Text(0.5, 1.0, 'Company Revenue')]

# %%
def currency(x, pos):
    """The value and position of the tick in question"""
    if x >= 1e6:
        s = "${:1.1f}M".format(x * 1e-6)
    else:
        s = "${:1.0f}K".format(x * 1e-3)
    return s


fig, ax = plt.subplots(figsize=(8, 4))
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment="right")
ax.set(
    xlim=[-10000, 140000],
    xlabel="Total Revenue",
    ylabel="Company",
    title="Company Revenue",
)
ax.xaxis.set_major_formatter(currency)

# %%
plt.style.use("seaborn-v0_8-pastel")
fig, ax = plt.subplots(figsize=(8, 4))
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment="right")

ax.axvline(group_mean, ls="--", color="r")

for group in [3, 5, 8]:
    ax.text(145000, group, "New Company", fontsize=10, verticalalignment="center")

ax.title.set(y=1.05)

ax.set(
    xlim=[-10000, 140000],
    xlabel="Total Revenue",
    ylabel="Company",
    title="Company Revenue",
)
ax.xaxis.set_major_formatter(currency)
ax.set_xticks([0, 25e3, 50e3, 75e3, 100e3, 125e3])
fig.subplots_adjust(right=0.1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 17
#      15 ax.xaxis.set_major_formatter(currency)
#      16 ax.set_xticks([0,25e3,50e3,75e3,100e3,125e3])
# ---> 17 fig.subplots_adjust(right=.1)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py:1336, in FigureBase.subplots_adjust(self, left, bottom, right, top, wspace, hspace)
#    1331     _api.warn_external(
#    1332         "This figure was using a layout engine that is "
#    1333         "incompatible with subplots_adjust and/or tight_layout; "
#    1334         "not calling subplots_adjust.")
#    1335     return
# -> 1336 self.subplotpars.update(left, bottom, right, top, wspace, hspace)
#    1337 for ax in self.axes:
#    1338     if ax.get_subplotspec() is not None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py:152, in SubplotParams.update(self, left, bottom, right, top, wspace, hspace)
#     147 """
#     148 Update the dimensions of the passed parameters. *None* means unchanged.
#     149 """
#     150 if ((left if left is not None else self.left)
#     151         >= (right if right is not None else self.right)):
# --> 152     raise ValueError('left cannot be >= right')
#     153 if ((bottom if bottom is not None else self.bottom)
#     154         >= (top if top is not None else self.top)):
#     155     raise ValueError('bottom cannot be >= top')
#
# ValueError: left cannot be >= right
